# %% [markdown]
# ## Exercise 1
# 1. Создайте график $x^2⋅sin(1/x^2)+x$ на интервале $[−1,1]$, используя 250 точек. Не забудьте пометить оси!
# 2. Создайте semilogy график (с логарифмической шкалой для оси y и линейной шкалой для оси x) относительной разницы  функций $1/(1+x^2)$ и $1/x^2$ на интервале $[5,25]$. (Относительная разница чисел $a$ и $b$ определяется как $|1−a/b|$)
# 3. В Scipy также есть много менее распространенных специальных функций. Взгляните на обширный список <a href=https://docs.scipy.org/doc/scipy/reference/special.html> здесь</a>! Выберите несколько интересных спец функций, которые вы знаете (или, может быть, не знаете), подставьте несколько чисел и начертите их.

# %% [markdown]
# ## Exercise 2
# 1. Построить график функции $sin(x)/x$ на отрезке $[-6\pi;6\pi]$ и добавить тики по оси $x$ с шагом $\pi/2$ от $-6\pi$ до $6\pi$, причём обозначения тиков должны содержать греческую букву $\pi$. Добавить сетку на график.

# %% [markdown]
# ## Exercise 3
# 1. Создайте цветовой график $sin(x)sin(y)$ на интервале $[−π,π]×[−π,π]$.
# 2. Создайте цветовой график $e^{-x^2-y^2}$ на интервале $[−3,3]×[−3,3]$.

# %% [markdown]
# EXERCISE 1

# %% [markdown]
# 1. Создайте график  𝑥2⋅𝑠𝑖𝑛(1/𝑥2)+𝑥  на интервале  [−1,1] , используя 250 точек. Не забудьте пометить оси!

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy.special

# %%
pip install special
# Out:
# Collecting special
#   Downloading special-0.1.5-py2.py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 475.0 kB/s eta 0:00:00a 0:00:01
# Collecting cython
#   Downloading Cython-0.29.35-py2.py3-none-any.whl (988 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 988.4/988.4 kB 3.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from special) (1.24.3)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from special) (1.10.1)
# Collecting astropy
#   Downloading astropy-5.3-cp311-cp311-macosx_10_9_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 3.7 MB/s eta 0:00:0000:0100:01m
# Collecting emcee==2.2.1
#   Downloading emcee-2.2.1.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting corner
#   Downloading corner-2.2.2-py3-none-any.whl (15 kB)
# Collecting nestle
#   Downloading nestle-0.2.0.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ultranest
#   Downloading ultranest-3.5.7.tar.gz (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 634.9 kB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... -^C
# anceled
# ERROR: Operation cancelled by user
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
x = np.linspace(-1, 1, 250)
y = (x**2*np.sin(1/x**2))+x
fig, ax = plt.subplots(figsize=(8,5))
plt.plot(x, y, color = 'red')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

# %% [markdown]
# 2. Создайте semilogy график (с логарифмической шкалой для оси y и линейной шкалой для оси x) относительной
# разницы функций  1/(1+𝑥2) и  1/𝑥2  на интервале  [5,25] . (Относительная разница чисел  𝑎  и  𝑏  определяется как
# |1−𝑎/𝑏| )

# %%
x = np.linspace(5,25)
y = abs(1-((1/(1+x**2))/(1/x**2)))

fig, ax = plt.subplots(figsize=(8,5))
ax.semilogy(x, y, color = 'green', linestyle='-.')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.grid()

# %% [markdown]
# 3. В Scipy также есть много менее распространенных специальных функций. Взгляните на обширный список <a href=https://docs.scipy.org/doc/scipy/reference/special.html> здесь</a>! Выберите несколько интересных спец функций, которые вы знаете (или, может быть, не знаете), подставьте несколько чисел и начертите их.

# %%
from scipy.special import j1, i0e, i1e


x = np.linspace(5, 20, 500)
plt.figure(figsize = (10, 10))
plt.title('Faster versions of common Bessel functions')

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x, j1(x), color = 'black', linestyle = '--')
plt.plot(x, i0e(x), color = 'yellow')
plt.plot(x, i1e(x), color = 'brown')
plt.grid()
plt.legend(loc='best')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
xx = np.linspace(- 5, 5, 2000)
yy = scipy.special.gamma(xx)
fig, ax = plt.subplots(figsize=(5,5))

ax.plot(xx, yy, color='yellow')
plt.xlim(-5, 5)
plt.ylim(6, 25)
plt.grid()
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# EXERCISE 2

# %% [markdown]
# Построить график функции  𝑠𝑖𝑛(𝑥)/𝑥  на отрезке  [−6𝜋;6𝜋]  и добавить тики по оси  𝑥  с шагом  𝜋/2  от  −6𝜋  до  6𝜋 , причём обозначения тиков должны содержать греческую букву  𝜋 . Добавить сетку на график.

# %%
def func_sin(x):
    return np.sin(x) / x

ox = np.linspace(-6*np.pi, 6*np.pi, 250)

plt.figure(figsize=(15, 8))
plt.plot(ox, func_sin(ox))

x_axis = [(str(-12+i) + 'π/2' if i != 12 else '0') for i in range(25)]
plt.xticks(np.arange(-6*np.pi, 6*np.pi+np.pi/2, np.pi/2), x_axis)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

# %% [markdown]
# EXERCISE 3

# %% [markdown]
# 1. Создайте цветовой график  𝑠𝑖𝑛(𝑥)𝑠𝑖𝑛(𝑦)  на интервале  [−π,π]×[−π,π] .

# %%
xx = np.linspace(-np.pi, np.pi, 150)
yy = np.linspace(-np.pi, np.pi, 150)
X, Y = np.meshgrid(xx, yy)
Z = np.sin(X) * np.sin(Y)
fig, ax = plt.subplots(figsize=(6, 5))

norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())
p = ax.pcolor(X, Y, Z, cmap='summer')

ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# 2. Создайте цветовой график  𝑒−𝑥2−𝑦2  на интервале  [−3,3]×[−3,3]

# %%
xx = np.linspace(-3, 3, 150) 
yy = np.linspace(-3, 3, 150)
X, Y = np.meshgrid(xx, yy)
Z = np.exp(- np.power(X, 2) - np.power(Y, 2))
fig, ax = plt.subplots(figsize=(6, 5))

norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())
p = ax.pcolor(X, Y, Z, norm=norm, cmap='autumn', shading='auto')


ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')
